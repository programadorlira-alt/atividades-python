# %% [markdown]
# <a href="https://colab.research.google.com/github/programadorlira-alt/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01-Introdução ao python

# %%
print("Olá,mundo!")
print("Curso Técnico em Informatica")
# Out:
# Olá,mundo!
# Curso Técnico em Informatica

# %%
disciplina=input("Digite o nome da disciplina:")
conteudo=input("Digite o conteúdo estudado:")
atividade=input("Digite o número da atividade:")
# Out:
# Digite o nome da disciplina:algoritimo e logica da programação
# Digite o conteúdo estudado:python
# Digite o número da atividade:01

# %%
print("\n---Informações da atividade---")
print("Disciplina:",disciplina)
print("Conteúdo:",conteudo)
print("Atividade:",atividade)
# Out:
# ---Informações da atividade---
# Disciplina: algoritimo e logica da programação
# Conteúdo: python
# Atividade: 01
